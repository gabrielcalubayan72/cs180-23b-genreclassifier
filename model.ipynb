# %%
#ok lets do this haha

# %%
#import necessary libraries

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
import nltk as nltk
from nltk.corpus import stopwords
import string

# %%
# Load the CSV file
data = pd.read_csv('processed_lyrics.csv')

# %%
# Extract the column names
column_names = data.columns.tolist()

# Print the column names
print("Column Names:", column_names)
# Out:
# Column Names: ['title', 'tag', 'artist', 'year', 'views', 'features', 'lyrics', 'id', 'language_cld3', 'language_ft', 'language', 'lyric_length']

# %%
# Assume the lyrics are in a column named 'lyrics' and the genres are in a column named 'tag'
lyrics = data['lyrics']
genre = data['tag']
# Out:
# 0       nang unang bibira mabomba bara mag ihaw gamit ...
# 1       alak balak lasing kasalukuyan ngunit malaman a...
# 2       hook ian tayao akoy tutula mahaba nako umupo p...
# 3       hook denise mamang pulis pwede ba akong huming...
# 4       pagbiyan mo puso umibig katulafd mo limutin yo...
#                               ...
# 7287    stanza alam mo bang mahal mahal kita tumatagal...
# 7288    1 hirang tingin mo lang nabighani iyoy nahiban...
# 7289    kanina nag iisip pano magagawa yung plano di n...
# 7290    pasa mo hayaan mo usok enerhiya dala kusang ma...
# 7291    sabado night sabado night sabado night sabado ...
# Name: lyrics, Length: 7292, dtype: object

# %%
# Extracting the vocabulary 
from collections import Counter

# Apply basic splitting to each of the lyrics
split_lyrics = data['lyrics'].apply(lambda x: x.split())

# Ensure each list contains only unique words
each_unique_words = split_lyrics.apply(lambda x: list(set(x)))

# Combine all lists into one list
all_words_list = [word for sublist in each_unique_words for word in sublist]

# Extract overall unique words list and label as vocab
vocab = unique_words = set(all_words_list)

# Number of unique words
num_elements = len(vocab)
# Out:
# {'dolphine',
#  'maaga',
#  'forevers',
#  'maghahangad',
#  'kritisismo',
#  'gising',
#  'reporter',
#  'barato',
#  'inaaping',
#  'dreadlocks',
#  'kalsada',
#  'sasapit',
#  'nagtakaka',
#  'solusyon',
#  'nambulag',
#  'budoy',
#  'kahulihulihan',
#  'milya',
#  'nalalatayan',
#  'nagiisang',
#  'harangin',
#  'hangin',
#  'lawit',
#  'pagtuklas',
#  'temperature',
#  'nagsisimba',
#  'magkachansa',
#  'ayaing',
#  'naitatanggi',
#  'lumagpas',
#  'siglaw',
#  'teresita',
#  'jerome',
#  'isisisi',
#  'malampasan',
#  'nadaing',
#  'pangako‚',
#  'paghigugma',
#  'kaleche',
#  'makaiwas',
#  'umihi',
#  'pamilyang',
#  'matud',
#  'nangangate',
#  'iniregalo',
#  'marandaman',
#  'saga',
#  'mind',
#  'tender',
#  'madarama',
#  'na…',
#  'susubuking',
#  'casino',
#  'ehersisyo',
#  'purket',
#  'kalaitan',
#  'prayed',
#  'maduduming',
#  'interludesolo',
#  'nilalaman',
#  'pinapasabik',
#  'emotions',
#  'nadaig',
#  'paging',
#  'notebook',
#  'pangiiwan',
#  'ribbon',
#  'ohhhoh',
#  'hippienghippie',
#  'makiliti',
#  'gulot',
#  'magpapatawag',
#  'isalang',
#  'inumagang',
#  'ipagdadrive',
#  'makaatake',
#  'binigay',
#  'pagkalami',
#  'pamangkin',
#  'magalukso',
#  'aziatik',
#  'prenopreno',
#  'makalaglag',
#  'disiotso',
#  'pagmasid',
#  'aserooooo',
#  'kontraktwalisasyon',
#  'kanlungan',
#  'cam',
#  'dahi',
#  'pagpupumilit',
#  'whistle',
#  'waiian',
#  'makontrol',
#  'maangan',
#  'nagdedeliryo',
#  'totoo”',
#  'aba’t',
#  'napaulan',
#  'bright',
#  'tristan',
#  'prinitong',
#  'karel',
#  'minus',
#  'stokes',
#  'buwang',
#  'shout',
#  'nagkapunitpunit',
#  'magcreate',
#  'hinigaan',
#  'akingpagasa',
#  'tayu',
#  'magtatagpi',
#  'kasiguradong',
#  'kanialang',
#  'kauhawan',
#  'nangandoy',
#  'pagpapasya',
#  'palpitate',
#  'pangitaing',
#  'ya',
#  'mangapi',
#  'sinamahan',
#  'iaabot',
#  'gabie',
#  'niagi',
#  'palingonlingon',
#  'hola',
#  'masgreedy',
#  'sususriin',
#  'lumawa',
#  'binabagsakan',
#  'bumukas',
#  'pagtulungtulungan',
#  'naglain',
#  'ngat',
#  'humahagkan',
#  'mawawaglit',
#  'defensive',
#  'ayayay',
#  'barahan',
#  'siphayo',
#  'hinihiwa…',
#  'mananataling',
#  'sumisigaw',
#  'biscuits',
#  'attencion',
#  'dpryme',
#  'bidlisiw',
#  'against',
#  'lalong',
#  'magkausap',
#  'katanungan',
#  'aagos',
#  'kilometrong',
#  'mj',
#  'inyoy',
#  'inaayon',
#  'bubuohin',
#  'silanganan',
#  'hinuhubad',
#  'salidang',
#  'nagaaliw',
#  'mikroponong',
#  'pupulbusin',
#  'makakauwi',
#  'mapurol',
#  'dipende',
#  'kakamotkamot',
#  'kakanti',
#  'pagsayang',
#  'nastress',
#  'mandin',
#  'magpapakatino',
#  'magalanganin',
#  'bohol',
#  'mabaon',
#  'nakalabas',
#  'swagg',
#  'nakakaadik',
#  'disoras',
#  'nanghihina',
#  'kulurete',
#  'ramihan',
#  'saa’y',
#  'sanman',
#  'gitnanng',
#  'dihog',
#  'pagsintay',
#  'pukawa',
#  'mapasaakin',
#  'nakahakbang',
#  'kumabisado',
#  'nagtabisay',
#  'magsisi',
#  'itadhana',
#  'kordero',
#  'namemerwisyong',
#  'himpapawiran',
#  'pasensiya',
#  'tempra',
#  'braso',
#  'tagas',
#  'into',
#  'alsa',
#  'binibring',
#  'kagaguhan',
#  'diktahan',
#  'puminta',
#  'inaangat',
#  'populated',
#  'oooh…',
#  'pagsasamantala',
#  'basurahan',
#  'pagnagsawa',
#  'masasangkot',
#  'mamanas',
#  'napagusapan',
#  'magpepedicab',
#  'rhyma',
#  'fer',
#  '😂',
#  'umiigting',
#  'pagkatao',
#  'nakaduster',
#  'bumaka',
#  'naggagayaw',
#  'istribo',
#  'bls',
#  'postibo',
#  'pangalangaang',
#  'ibaling',
#  'nakakastress',
#  'wooohhwoohh',
#  'masamang',
#  'tistigo',
#  'tumitimbang',
#  'papahuli',
#  'ikotbarkada',
#  'sandals',
#  'nabitawan',
#  'nakisabay',
#  'lusot',
#  'mapanupil',
#  'kontakin',
#  'panandalian',
#  'bubuti',
#  'cheddar',
#  'nagkahati',
#  'paghug',
#  'covid19',
#  'isanay',
#  'bumabait',
#  'pupumilit',
#  'akalin',
#  'gegets',
#  'iimbento',
#  'padaliin',
#  'naiinspire',
#  'nagiiyakan',
#  'aaklas',
#  'ahhhhohhh',
#  'ipapahatid',
#  'sagipin',
#  'puos',
#  'pakakaingatan',
#  'nangaapi',
#  'buwagen',
#  'perfect',
#  'nauugnay',
#  'inaakala',
#  'pao',
#  'maglalasing',
#  'taong',
#  'seafoods',
#  'husgahan',
#  'susulitiin',
#  'sakitan',
#  'maulansisikat',
#  'nagmana',
#  'eng',
#  'alitaptap',
#  'weakest',
#  'mangagalin',
#  'cojuangco',
#  'aminin',
#  'tumuhog',
#  'amag',
#  'huddass',
#  'magdiriwang',
#  'tutusok',
#  'abroche',
#  'pasagutin',
#  'kelangang',
#  'naghihilamos',
#  'kalapitan',
#  'tumatandang',
#  'inaang',
#  'mapanglito',
#  'mitsubishi',
#  'bighani',
#  'maihelera',
#  'nabuksan',
#  'magsisimbang',
#  'matutuhay',
#  'crakky',
#  'pagsalita',
#  'bumakat',
#  'manghuhulang',
#  'hita',
#  'handumanan',
#  'mamamanhid',
#  'raw',
#  'mapadpad',
#  'lov',
#  'faithful',
#  'alat',
#  'paliit',
#  'pumuri',
#  'mapapansin',
#  'kwarta',
#  'pampalit',
#  'nakakaparalisa',
#  'throwing',
#  'pinagsiksikan',
#  'sinugdan',
#  'kila',
#  'though',
#  'intresado',
#  'aasa',
#  'sansinukuban',
#  'magkapantay',
#  'nagkakalitulito',
#  'paghihiwalay',
#  'pumapayat',
#  'kagubata’y',
#  'tamaan',
#  'nagkabuholbuhol',
#  'inaalikabok',
#  'nikalit',
#  'pinagtripan',
#  'tachiagaru',
#  'raramdaman',
#  'dakilain',
#  'lelelelechon',
#  'tigasan',
#  'pinapasan',
#  'barkong',
#  'ikembotkembot',
#  'nakilimutan',
#  'ikanta',
#  'pananalangit',
#  'niyuyurakan',
#  'nakikipasada',
#  'wohhoo',
#  'lulupig',
#  'pakita',
#  'sinlaya',
#  'mangangambang',
#  'magalet',
#  'aaaww',
#  'sumasangguni',
#  'pyalungan',
#  'papupurihan',
#  'naisuka',
#  'magkasaket',
#  'purong',
#  'tutal',
#  'valentines',
#  'napakahina',
#  'kasaya',
#  'place',
#  'naitago',
#  'dedicated',
#  'ten',
#  'magsigarilyo',
#  'napaingles',
#  'naabsorb',
#  'kabata',
#  'tiwalang',
#  '÷',
#  'binay',
#  'pasimuno',
#  'flow',
#  'alamang',
#  'ikamahay',
#  'pagsyota',
#  'nakakasado',
#  'ipanumpa',
#  'dadaaan',
#  'nakakaimbalido',
#  'cerby',
#  'pakukulong',
#  'bukayo',
#  'gatil',
#  'alikabog',
#  'papatunayan',
#  'alarma',
#  'mata',
#  'pagsambit',
#  'hugot',
#  'police',
#  'spoliarium',
#  'hatiin',
#  'mapilita',
#  'gon',
#  'maprapraning‚',
#  'nakapiling',
#  'digest',
#  'akakapigil',
#  'tangkang',
#  'magkahati',
#  'komediya',
#  'masantabi',
#  'napakinggan',
#  'nagmistulang',
#  'pagnilusong',
#  'tinatakam',
#  'bakaireject',
#  'aakayain',
#  'tinitipid',
#  'hindi’t',
#  'masandad',
#  'papaluin',
#  'santong',
#  'makamtanngayon',
#  'magpatihulog',
#  'dakpin',
#  '3blkd',
#  '“grabeng',
#  'cruise',
#  'dagdagsahod',
#  'pumipinta',
#  'ibabayad',
#  'magpaselponselpon',
#  'comfingcomfy',
#  'pagwawakas',
#  'jac',
#  'nanggigigil',
#  'dinaman',
#  'manananggal',
#  'basta',
#  'nagwalang',
#  'mapapawow',
#  'nagkatotoo',
#  'hinandang',
#  'chem',
#  'sesexy',
#  'paligo',
#  'nakakahapo',
#  'hina’in',
#  'papatirin',
#  'muto',
#  'oow',
#  'andaya',
#  'ginagawin',
#  'napakagaling',
#  'taasnoong',
#  'naglakaw',
#  'paboritong',
#  'babaliktad',
#  'mamamayagpag',
#  'silaw',
#  'ipinaabot',
#  'hulian',
#  'iniiisip',
#  'abuloy',
#  'malat',
#  'kwartong',
#  'nabalik',
#  'ohhohh',
#  'monang',
#  'tatayatayaan',
#  'nakukuha',
#  'mananatili',
#  'panaglalis',
#  'kahangturan',
#  'nakaalalay',
#  'pinahanga',
#  'miney',
#  'makalimutan',
#  'valdez',
#  'ro',
#  'months',
#  'makabulohan',
#  'uuntiuntiin',
#  'gud',
#  'suportat',
#  'pasasakitan',
#  'kumakalam',
#  'mothu',
#  'napatibok',
#  'tawatawanan',
#  'tung',
#  'alembong',
#  'komplika',
#  'dumudugo',
#  'salungguhit',
#  'mapagisipan',
#  'magniningning',
#  'dabara',
#  'keep',
#  'pagasagdi',
#  'sundan',
#  'ikaï¿½y',
#  'saxophone',
#  'lalakas',
#  'naising',
#  'pagdududahan',
#  'agarang',
#  'pinagugnay',
#  'simbolo',
#  'namamansin',
#  'kailaaaan',
#  'mangungutya',
#  'mang',
#  'lumapat',
#  'lang’',
#  'directahan',
#  'magflex',
#  'yuji',
#  'landing',
#  'lolay',
#  'pwestuhan',
#  'ak0',
#  'maghawakhawak',
#  'nakikipagtalik',
#  'ngaunit',
#  'cred',
#  'taguan',
#  'ay’',
#  '24',
#  'volcanic',
#  'se',
#  'far',
#  'nawawalay',
#  'lisanin',
#  'nararanasan',
#  'piitan',
#  'natitilihang',
#  'anhia',
#  'malimulimut',
#  'raf',
#  'salisalitaang',
#  'bulldozer',
#  'nagtuturo',
#  'kaninong',
#  'saang',
#  'magsimula',
#  'panganinag',
#  'bigas',
#  'magdalawang',
#  'bayarang',
#  'consuelo',
#  'iniisnub',
#  'sagad',
#  'mapagbiyan',
#  'mahita',
#  'magbibiruan',
#  'kagahapon',
#  'upo',
#  'kakulay',
#  'coming',
#  'pagtitinginan',
#  'paeng',
#  'lumapit',
#  'tsibugin',
#  'tagasaing',
#  'napapanis',
#  'celebrity',
#  'ningning',
#  'nabunutan',
#  'malakbay',
#  'duo’y',
#  'ipatong',
#  'aasikasuhin',
#  'nagbigay',
#  'makipaggitgitan',
#  'starbesyon',
#  'pamemerwisyo',
#  'gangtas',
#  'umaga’ng',
#  'dibidendo',
#  'mustasa',
#  'minamsahe',
#  'namumunoy',
#  'pali',
#  'patalasan',
#  'sakaleng',
#  'gettin',
#  '‘kong',
#  'sinsadyang',
#  'lamanloob',
#  'kinaadikan',
#  'kuskos',
#  'inadd',
#  'paiyakin',
#  'ngumunguya',
#  'nagtiniil',
#  'gasong',
#  'opisyo',
#  'nagdiriwang',
#  'balibaliktarin',
#  'bubuo',
#  'lid',
#  'panagutan',
#  '’dyang',
#  'lalapitan',
#  'makasayaw',
#  'papapaparapara',
#  'pumera',
#  'asya',
#  'parada',
#  'kulisap',
#  'paglaklakbay',
#  'kusing',
#  'nakagawa',
#  'gugustohin',
#  'gunfire',
#  'papasabik',
#  'queen',
#  'panonood',
#  'umiisip',
#  'aminan',
#  'natuwa',
#  'umaagos',
#  'nagoffer',
#  'reply',
#  'sumuporta',
#  'panggulat',
#  'badly',
#  'pagkakalito',
#  'mataranta',
#  'nagkaganun',
#  'hablo',
#  'makakapagligtas',
#  'napaswimming',
#  'kathangisip',
#  'nakagapos',
#  'gumambala',
#  'paikot',
#  'imba',
#  'makipagsabayan',
#  'swing',
#  'mahakot',
#  'mamamaalam',
#  'bagyo’t',
#  'dadaing',
#  'kaayuhan',
#  'manamet',
#  'pipiglas',
#  'papaikutin',
#  'tatawaging',
#  'loser',
#  '“para',
#  'humor',
#  'kayax8',
#  'literaturang',
#  'paiiralin',
#  'nadadaanang',
#  'lagig',
#  'manoy',
#  'yeji',
#  'chinita',
#  'nilalampaso',
#  'pupuntuhan',
#  'innozent',
#  'dumadali',
#  'magpakadisente',
#  'pittsburgh',
#  'minsanminsan',
#  'sarhan',
#  'napakatino',
#  'pagtawa',
#  'offbeat',
#  'wahh',
#  'binitin',
#  'macho',
#  'sabihan',
#  'kumukulong',
#  'pinapasok',
#  'nestle',
#  'impact',
#  'usong',
#  'bibliyat',
#  'argh',
#  'tsikot',
#  'sinulong',
#  'taeyang',
#  'gingham',
#  'takipmata',
#  'pwertahan',
#  'hastang',
#  'rеmedy',
#  'nahalina',
#  'lumay',
#  'julius',
#  'makaako',
#  'nagflying',
#  '😢',
#  'kapuyan',
#  'noong',
#  'katukayo',
#  'mauswagon',
#  'tanso',
#  'landi',
#  'nanadya',
#  '‘dong',
#  'yours',
#  'kinamumuhian',
#  'woooaaah',
#  'realize',
#  'asada',
#  'natataob',
#  'goma',
#  'presyon',
#  'limpyohan',
#  'daze',
#  'pinakapangarap',
#  'sinung',
#  'magkamit',
#  'babagay',
#  'tube',
#  'abuting',
#  'dinamiramj',
#  'tuwang',
#  'doet',
#  'jurabol',
#  'kalangan',
#  'ofel',
#  'tagginaw',
#  'sayangin',
#  'rumarampa',
#  'toshiba',
#  'ref',
#  'nasiko',
#  'makapagtiis',
#  'mahangkan',
#  'bibiyahe',
#  'ba’t',
#  'ale',
#  'perti',
#  'mopalayo',
#  'mapapaluhod',
#  'convinced',
#  'maisalarawan',
#  'iparanas',
#  '800',
#  'dinidinig',
#  'laaaang',
#  'umaangkas',
#  'pampagaan',
#  'mapilit',
#  'hunyango',
#  'magkamagkahiusa',
#  'darwin',
#  'hinaharang',
#  'sya',
#  'pinapagawa',
#  'pinagtagal',
#  'aktibong',
#  'niya’y',
#  'valentina',
#  'dana',
#  'hothothothot',
#  'same',
#  'nagkadahilan',
#  'sanina',
#  'pahirap',
#  'backseat',
#  'pictures',
#  'hawak',
#  'ibibigay',
#  'masmabaho',
#  'pagtingala',
#  'manghugsa',
#  'rjay',
#  'natutulalaumiiyaktumatawa',
#  'pinagmulang',
#  'nagsisikibuan',
#  'aparri',
#  'nananalaytay',
#  'bungod',
#  'makipagkapwatao',
#  'checkmate',
#  'estrella',
#  'kalabaw',
#  'maghimay',
#  'nagkapikunan',
#  'maoolats',
#  'papalitan',
#  'ginoyo',
#  'napipikon',
#  'napapawing',
#  'baterya',
#  'magdungag',
#  'brain',
#  'makaramda',
#  'makapiglas',
#  'panguusap',
#  'luha’t',
#  'dumidistansiya',
#  'whawhawhawhawha',
#  'alltime',
#  'kapansanang',
#  'paingnan',
#  'meksikano',
#  'parepare',
#  'kaawan',
#  'minasdan',
#  'nasumhan',
#  'makachat',
#  'pala…hindi',
#  'suungin',
#  'mupadayon',
#  'maaabot',
#  'bagay',
#  'nagibgay',
#  'pinagabang',
#  'nandirito',
#  'pagbabayanihan',
#  'sentimyento',
#  'sasabik',
#  'mababalian',
#  'sulô',
#  'pinararangalan',
#  'lend',
#  'nangangahulugan',
#  'gumana',
#  'kagustuhang',
#  'pinakamatulen',
#  'bumabadyang',
#  'kesot',
#  'matirhan',
#  'sisipat',
#  '’yo’y',
#  'mabagok',
#  'popx',
#  'magpakulong',
#  'pool',
#  'malooy',
#  'teple',
#  'pakig',
#  'that',
#  'malimutlimot',
#  'kuman',
#  'misteriosa',
#  'saya’y',
#  'sleepin',
#  'indorser',
#  'sweets',
#  'ipagsabay',
#  'usaon',
#  'joie',
#  'panglakwatsa',
#  'nagkaibigan',
#  'bawas',
#  'mahigpit',
#  'pasalubong',
#  'sayo…sayo',
#  'nagpatongpatong',
#  'pinipisil',
#  'tuldok',
#  'bahagharing',
#  'manumbat',
#  'enerhiyang',
#  'hanapin',
#  'sinisingit',
#  'sentensya',
#  'owe',
#  'street',
#  'jaws',
#  'harmony',
#  'malajose',
#  'hasa',
#  'kumpeto',
#  'sapitin',
#  'hanggin',
#  'kinakalkulang',
#  'nakasigaw',
#  'traidor',
#  'memorandum',
#  'nilalanggam',
#  'handlе',
#  'itigis',
#  'nagawaahah',
#  'nagulat',
#  'pagbabakasakali',
#  'tadyakan',
#  'magapapalusot',
#  'budah',
#  'planetang',
#  'makktown',
#  'napakabalisa',
#  'ibibigaylamang',
#  'babasagin',
#  'nlang',
#  'pagtinigin',
#  'magpophotoshoot',
#  'napapasabay',
#  'naniniwalala',
#  'masayangmasaya',
#  'night',
#  'maihatid',
#  'inuuna',
#  'maggupit',
#  'magpapamisa',
#  'mariajuana',
#  'gagaya',
#  'salarin',
#  'nasamad',
#  'moog',
#  'self',
#  'safesafesafesafesafe',
#  'nakapakit',
#  'solyuson',
#  'umaamoy',
#  'pipigtas',
#  'musician',
#  'jump',
#  'binebentang',
#  'nagloloko',
#  'haula',
#  'warningan',
#  'tagapagtayo',
#  'matapang',
#  'babangitin',
#  'iningatang',
#  'magabroad',
#  'pinapakabisa',
#  'magpiko',
#  'wrapper',
#  'binaggit',
#  'kababaw',
#  'effort',
#  'kakapuyat',
#  'paulitulitulitulit',
#  'mutyang',
#  'somethin',
#  'maglovingloving',
#  'yordn',
#  'patilawog',
#  'akun',
#  'minabuting',
#  'koloretes',
#  'magon',
#  'crema',
#  'padaig',
#  'cardi',
#  'mauling',
#  'kinatawang',
#  'patutunayang',
#  'igsuon',
#  'makatagal',
#  'nakakaiba',
#  'pigangpiga',
#  'laitin',
#  'dumadalas',
#  'rak',
#  'nagpatibay',
#  'east',
#  'lesbian',
#  'landilandi',
#  'makakanakaw',
#  'nagpadagdaglaman',
#  'lahatmga',
#  'batanggenyo',
#  'likе',
#  'napapaputang',
#  'teynga',
#  'mananiniwala',
#  'pasapat',
#  'mabubuti',
#  'hindihindi',
#  'pakshit',
#  'hhhmmm',
#  'umpisa',
#  'kahumpay',
#  'binubulag',
#  'maghahasik',
#  'daanin',
#  'tanggihan',
#  'pagdasig',
#  'moymoy',
#  'pinty',
#  'recognition',
#  'pupwede',
#  'cris',
#  'kahilum',
#  'dayum',
#  'maniwalang',
#  'hyss',
#  'saya',
#  'alalayan',
#  'ninakawan',
#  'magpalabaw',
#  'maghawakkamay',
#  'nalunon',
#  'avyllanzeta',
#  'blow',
#  ...}
